# %% [markdown]
# ## Project 2020
# ### Programming for Data Analysis
# #### Aim:
#
# - Choose a real-world phenomenon that can be measured - gather 100 datapoints across 4 variables
# - Investigate the types of variables involved , their likely distributions and relationships with each other
# - Simulate a Dataset as closely matching their properties as possible
# - Detail your research and implement the simulation in a jupyter notebook
# - Create a git repository

# %% [markdown]
# #### Introduction
#
#
# The real-world phenonmenon I have choosen is the topic of feeding babies and the options , support given to mothers in ireland. The reference point is the National Maternity Experience Survey.
# Women age 16 and over who gave birth in October/November of 2019 and was also resident of Ireland took part in  survey .A total of 3,204 women was surveyed in 19 participating maternity hospitals/units and home birth services. There was 6 topics covered and one of them was Feeding where the result was 7.8 out of 10 response. This section was highlighted as an area of needed improvement. This topic is personal to me as I myself am a new mother.
#
# Using the real-life percentage results from this section of the survey , I am going simulate/ create a dataset to show results of the types of feeding and the level of support. I would to see if there is a relationship between the level of support and the choice of feeding selected by the new mothers in the first few days.
#
# List of Hospitals Taking part :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### The distributions and relationships between the variables
#
# ##### Investigate the types of variables involved, their likely distributions, and their relationships with each other.
#
# Using the National Maternity Experience Survey as a reference , I reviewed the sections covered and the questions asked. One of the lowest scoring questions were based on Feeding and support. 15% of women said that while they were in the hospital they did not get adequate support or encouragement with feeding their baby. By Feeding , I mean breastfeeding mainly but will look at all other forms as well.  There is room for improvement here. Historicall , brestfeeding rates in ireland have been low compared with international averages.
#
# I decided to simulate a dataset containing results for the following variables and their influence on feeding choices especially breastfeeding for 500 new mothers.
#
# From the questions asked and answers , I choose the following a variables, trying to keep in line with the characteristics and  variables of the survey but changing if necessary to suit the purposes of simulating data. I also simulate the results in line with the survey results for each variable. For following variables , I will look at their impact on feeding especially breastfeeding :
#
#  - AgeProfile - ages <25, 25-30,30-35,35-40,<40
#
#  To have a good age range in order to examine if age has any impact on feeding choices.
#
#  - Ethnicity - White Irish','Roma','African','Chinese','Arabic','Asian','Mixed','Other'
#
#  Question asked : Has Ethnicity any impact on feeding choices ?
#
#  According to research , ethnicity does influence on breastfeeding initiation and duration. Looking at research results from 2019 , 55.9% ( 6202 out of 11,092) women initiated breastfeeding with only 7.9% continued breastfeeding until 9 months. However only 50% of Irish citizens (4693 of 9368) initiated breastfeeding compared to 88.7% of non-irish citizens ( 1503/1695).
#
#  - Hospitals - 19 hospitals and home birth services
#
#  Does the level of feeding support for mothers differ between the hospitals ?
#
#  - HospitalFeedingSupport - a score rating from 0- 10
#
#  During the mothers stay in hospital , did the healthcare professionals give adequate support and encouragement with feeding your baby ? Did this support influence your decision on the type of feeding you choose ?
#
#  - HomeFeedingSupport- a score rating from 0- 10
#
#  Once the mother was at home , did the healthcare professionals give adequate support and encouragement with feeding your baby ? Did this support influence your decision to continue or change your feeding choice ?
#
#  - FeedingChoices- Breast milk','breast /formula milk Combo','Formula (bottle) milk','Don’t know or can’t remember'
#
#  These are the feeding choices available and were initiated in the first week
#
#  - FeedingDecisionRespected - a score rating from 0- 10
#
#  Was the mothers feeding decision respected by the healthcare professionals ?
#
#   - Breastfeeding6months
#
#   Did the mothers who choose breastfeeding continue to at least 6 months ?

# %% [markdown]
# ### Variable 1 : AGE PROFILE
#
# ### Generate random values of age using Numpy.random function

# %%
# Generate age between 20 and 45 years old using the Percent probabilities from survey
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set()


AgeProfile =20,25,30,35,40
AgeProfile = np.random.choice(AgeProfile, 1000, p=[0.048, 0.141, 0.366, 0.358, 0.087]) 
AgeProfile

# Average age of the sample
np.mean(AgeProfile)
#np.median(AgeProfile)
# Out:
# 31.47

# %%
# Average age of the sample
import numpy as np
np.mean(AgeProfile)
#np.median(AgeProfile)
# Out:
# 31.22

# %% [markdown]
# #### The mean age is 31.22  which is in line the national average of 32.5 years

# %%
#Plot the age using a histogram to visualize the distribution of this variable
# Histogram

plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(AgeProfile, bins=10)
plt.xlabel('Age in years')

plt.show()

# %%
#Boxplot
import matplotlib.pyplot as plt
plt.boxplot(AgeProfile, showmeans=True)
plt.show()

# %% [markdown]
# ##### From the histogram above , we can see the peak ages for women is between 30 and 35. Also that the distribution is a normal , as from the boxplot , shows the mean and median are similar

# %% [markdown]
# ### Variable 2 : Ethnicity

# %%
Ethnicity= ['White Irish','Roma','African','Chinese','Arabic','Asian','Mixed','Other']

#Populate the Ethnicity column 
Ethnicity= np.random.choice(Ethnicity, 500, p=[0.939,0.003,0.014,0.004,0.004,0.017,0.01,0.009]) 
Ethnicity
# Out:
# array(['White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'Other', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'African', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'Asian', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'Other', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'Chinese', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'Asian', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'African', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'Other',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'African',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'Asian',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'African', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'Mixed', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'Asian', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'Mixed', 'White Irish', 'White Irish', 'African', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'African', 'White Irish', 'White Irish',
#        'White Irish', 'Asian', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'Other', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'Asian',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'Arabic', 'White Irish',
#        'White Irish', 'Chinese', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'Asian', 'White Irish', 'African', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'Roma', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'Other', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'Mixed', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish', 'White Irish', 'White Irish', 'African',
#        'White Irish', 'White Irish', 'White Irish', 'White Irish',
#        'White Irish'], dtype='<U11')

# %%
#Plot the Ethniticy using a histogram to visualize the distribution of this variable
# Histogram

plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(Ethnicity, bins=10)
plt.xlabel('Ethnicity')

plt.show()

# %% [markdown]
# Its obvious that the distribution of the variable Ethnicity is not a normal one. The majority ethnic group is white irish mothers surveyed.

# %% [markdown]
# ### Variable 3 : FeedingChoices

# %%
FeedingChoices = ['Breast milk','breast /formula milk Combo','Formula (bottle) milk','Don’t know or can’t remember' ]
FeedingChoices = np.random.choice(FeedingChoices, 500, p=[0.4,0.3,0.29,0.01])   
FeedingChoices
# Out:
# array(['Breast milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk', 'Breast milk',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'Breast milk', 'Breast milk', 'Don’t know or can’t remember',
#        'Breast milk', 'Breast milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk', 'Breast milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk',
#        'breast /formula milk Combo', 'Breast milk', 'Breast milk',
#        'Breast milk', 'Formula (bottle) milk', 'Breast milk',
#        'Breast milk', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'Breast milk',
#        'breast /formula milk Combo', 'Breast milk',
#        'Formula (bottle) milk', 'Formula (bottle) milk', 'Breast milk',
#        'breast /formula milk Combo', 'Breast milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'Breast milk', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Don’t know or can’t remember',
#        'Breast milk', 'Breast milk', 'Breast milk', 'Breast milk',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'Breast milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk', 'Breast milk',
#        'Breast milk', 'Breast milk', 'breast /formula milk Combo',
#        'Breast milk', 'Formula (bottle) milk', 'Formula (bottle) milk',
#        'Breast milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk', 'Breast milk',
#        'Breast milk', 'Breast milk', 'Formula (bottle) milk',
#        'Breast milk', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Breast milk', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Breast milk', 'Breast milk', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Breast milk', 'Breast milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'Breast milk', 'Breast milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Breast milk', 'Breast milk', 'Breast milk',
#        'Formula (bottle) milk', 'Breast milk', 'Breast milk',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'Breast milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk', 'Breast milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Breast milk', 'Formula (bottle) milk', 'Breast milk',
#        'Breast milk', 'Breast milk', 'breast /formula milk Combo',
#        'Breast milk', 'Breast milk', 'Breast milk',
#        'Formula (bottle) milk', 'Formula (bottle) milk', 'Breast milk',
#        'Breast milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk', 'Breast milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Breast milk',
#        'breast /formula milk Combo', 'Breast milk',
#        'Formula (bottle) milk', 'Breast milk', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'Breast milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Breast milk', 'Breast milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'Breast milk', 'breast /formula milk Combo', 'Breast milk',
#        'Breast milk', 'Breast milk', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'Breast milk', 'breast /formula milk Combo', 'Breast milk',
#        'Breast milk', 'Formula (bottle) milk', 'Breast milk',
#        'Breast milk', 'Breast milk', 'Breast milk', 'Breast milk',
#        'Breast milk', 'Breast milk', 'breast /formula milk Combo',
#        'Breast milk', 'Breast milk', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Breast milk', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'Breast milk', 'Breast milk',
#        'Breast milk', 'breast /formula milk Combo', 'Breast milk',
#        'Breast milk', 'Breast milk', 'Breast milk',
#        'Formula (bottle) milk', 'Breast milk', 'Breast milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk',
#        'Don’t know or can’t remember', 'Don’t know or can’t remember',
#        'Formula (bottle) milk', 'Breast milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'Breast milk', 'Breast milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Breast milk', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Breast milk', 'Formula (bottle) milk',
#        'Breast milk', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'Breast milk', 'Breast milk',
#        'breast /formula milk Combo', 'Breast milk', 'Breast milk',
#        'breast /formula milk Combo', 'Breast milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Breast milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'Breast milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Formula (bottle) milk', 'Breast milk',
#        'Breast milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'Breast milk', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'Breast milk',
#        'Formula (bottle) milk', 'Breast milk', 'Formula (bottle) milk',
#        'Breast milk', 'Breast milk', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'Breast milk', 'Breast milk',
#        'Breast milk', 'breast /formula milk Combo', 'Breast milk',
#        'Breast milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk', 'Breast milk',
#        'breast /formula milk Combo', 'Breast milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk', 'Formula (bottle) milk',
#        'Breast milk', 'Breast milk', 'Don’t know or can’t remember',
#        'Formula (bottle) milk', 'Breast milk', 'Breast milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Formula (bottle) milk', 'Breast milk',
#        'Breast milk', 'Breast milk', 'Breast milk', 'Breast milk',
#        'Formula (bottle) milk', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Formula (bottle) milk', 'Breast milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Formula (bottle) milk', 'Breast milk',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'Breast milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'Breast milk', 'Breast milk', 'breast /formula milk Combo',
#        'Breast milk', 'Breast milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'Breast milk', 'Breast milk', 'Formula (bottle) milk',
#        'Breast milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Don’t know or can’t remember',
#        'Breast milk', 'breast /formula milk Combo', 'Breast milk',
#        'Formula (bottle) milk', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Breast milk', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk',
#        'breast /formula milk Combo', 'Breast milk', 'Breast milk',
#        'Breast milk', 'Breast milk', 'Breast milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'Breast milk', 'Breast milk',
#        'Breast milk', 'Formula (bottle) milk', 'Formula (bottle) milk',
#        'Breast milk', 'Formula (bottle) milk', 'Breast milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'Breast milk', 'Breast milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'Breast milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Breast milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk', 'Formula (bottle) milk',
#        'Breast milk', 'Formula (bottle) milk', 'Breast milk',
#        'Breast milk', 'Breast milk', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Breast milk', 'Breast milk', 'Breast milk',
#        'breast /formula milk Combo', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'Breast milk',
#        'breast /formula milk Combo', 'Breast milk', 'Breast milk',
#        'Formula (bottle) milk', 'Breast milk', 'Formula (bottle) milk',
#        'Breast milk', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'Breast milk',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Breast milk', 'Breast milk',
#        'Breast milk', 'breast /formula milk Combo',
#        'Formula (bottle) milk', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'breast /formula milk Combo', 'Breast milk',
#        'Formula (bottle) milk', 'Breast milk', 'Breast milk',
#        'Breast milk', 'breast /formula milk Combo',
#        'breast /formula milk Combo', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Breast milk', 'Formula (bottle) milk',
#        'Breast milk', 'Breast milk', 'Breast milk',
#        'Formula (bottle) milk', 'Breast milk', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Formula (bottle) milk', 'Breast milk',
#        'Breast milk', 'Formula (bottle) milk', 'Breast milk',
#        'Formula (bottle) milk', 'Breast milk',
#        'breast /formula milk Combo', 'Breast milk', 'Breast milk',
#        'Breast milk', 'Breast milk', 'Formula (bottle) milk',
#        'Formula (bottle) milk', 'Breast milk', 'Breast milk'],
#       dtype='<U28')

# %%
#Plot the FeedingChoices using a histogram to visualize the distribution of this variable
# Histogram

plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(FeedingChoices, bins=10)
plt.xlabel('FeedingChoices')
plt.show()

# %% [markdown]
# ### Variable 4 : Hospitals

# %%
Hospitals = ['National Maternity Hospital',
             'Coombe Women and Infants University Hospital',
             'Cork University Maternity Hospital',
             'University Maternity Hospital Limerick',
             'Our Lady of Lourdes Hospital',
             'University Hospital Galway',
             'Cavan General Hospital',
             'Letterkenny University Hospital',
             'Mayo University Hospital',
             'Midland Regional Hospital Mullingar',
             'Midland Regional Hospital Portlaoise',
             'Portiuncula University Hospital',
             'Sligo University Hospital',
             'South Tipperary General Hospital',
             'St Luke’s General Hospital',
             'University Hospital Kerry',
             'University Hospital Waterford',
             'Wexford General Hospital',
             'National Home Birth Services',
             'Rotunda Hospital']

Hospitals = np.random.choice(Hospitals, 500, p=[0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.04, 0.05, 0.05, 0.04, 0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05])     
Hospitals
# Out:
# array(['Wexford General Hospital', 'South Tipperary General Hospital',
#        'Cork University Maternity Hospital',
#        'University Hospital Waterford', 'University Hospital Galway',
#        'Coombe Women and Infants University Hospital',
#        'University Hospital Waterford',
#        'Midland Regional Hospital Mullingar',
#        'Portiuncula University Hospital', 'Wexford General Hospital',
#        'Midland Regional Hospital Portlaoise',
#        'Midland Regional Hospital Portlaoise',
#        'University Hospital Kerry', 'Midland Regional Hospital Mullingar',
#        'Cavan General Hospital', 'Midland Regional Hospital Portlaoise',
#        'Rotunda Hospital', 'Coombe Women and Infants University Hospital',
#        'Cavan General Hospital', 'Portiuncula University Hospital',
#        'Wexford General Hospital', 'Our Lady of Lourdes Hospital',
#        'Wexford General Hospital', 'Sligo University Hospital',
#        'Midland Regional Hospital Portlaoise',
#        'Sligo University Hospital', 'Midland Regional Hospital Mullingar',
#        'Rotunda Hospital', 'St Luke’s General Hospital',
#        'National Home Birth Services', 'St Luke’s General Hospital',
#        'National Maternity Hospital',
#        'Midland Regional Hospital Mullingar', 'Mayo University Hospital',
#        'Our Lady of Lourdes Hospital', 'South Tipperary General Hospital',
#        'Wexford General Hospital',
#        'Coombe Women and Infants University Hospital',
#        'Mayo University Hospital', 'Mayo University Hospital',
#        'Sligo University Hospital', 'South Tipperary General Hospital',
#        'Letterkenny University Hospital', 'National Home Birth Services',
#        'Rotunda Hospital', 'National Maternity Hospital',
#        'National Maternity Hospital', 'Rotunda Hospital',
#        'University Maternity Hospital Limerick',
#        'Portiuncula University Hospital', 'University Hospital Waterford',
#        'Portiuncula University Hospital', 'Our Lady of Lourdes Hospital',
#        'South Tipperary General Hospital',
#        'Midland Regional Hospital Mullingar',
#        'Midland Regional Hospital Mullingar',
#        'University Hospital Galway',
#        'University Maternity Hospital Limerick',
#        'Cork University Maternity Hospital', 'Wexford General Hospital',
#        'Midland Regional Hospital Mullingar',
#        'Portiuncula University Hospital', 'Mayo University Hospital',
#        'National Home Birth Services', 'University Hospital Kerry',
#        'South Tipperary General Hospital',
#        'Coombe Women and Infants University Hospital',
#        'Cavan General Hospital', 'Midland Regional Hospital Portlaoise',
#        'South Tipperary General Hospital', 'National Maternity Hospital',
#        'Midland Regional Hospital Mullingar',
#        'Letterkenny University Hospital',
#        'University Maternity Hospital Limerick',
#        'University Hospital Waterford', 'Sligo University Hospital',
#        'University Hospital Galway', 'National Maternity Hospital',
#        'National Maternity Hospital', 'Letterkenny University Hospital',
#        'University Hospital Galway', 'University Hospital Galway',
#        'Letterkenny University Hospital',
#        'Letterkenny University Hospital',
#        'University Maternity Hospital Limerick',
#        'Our Lady of Lourdes Hospital', 'University Hospital Waterford',
#        'National Home Birth Services',
#        'Cork University Maternity Hospital',
#        'National Maternity Hospital', 'University Hospital Kerry',
#        'Coombe Women and Infants University Hospital',
#        'National Home Birth Services', 'University Hospital Waterford',
#        'Portiuncula University Hospital', 'Wexford General Hospital',
#        'National Home Birth Services', 'Portiuncula University Hospital',
#        'Letterkenny University Hospital',
#        'Portiuncula University Hospital',
#        'Midland Regional Hospital Portlaoise',
#        'University Hospital Waterford', 'Letterkenny University Hospital',
#        'University Hospital Galway', 'National Home Birth Services',
#        'Our Lady of Lourdes Hospital',
#        'University Maternity Hospital Limerick',
#        'University Hospital Waterford', 'Portiuncula University Hospital',
#        'Our Lady of Lourdes Hospital', 'Cavan General Hospital',
#        'Midland Regional Hospital Mullingar',
#        'Letterkenny University Hospital',
#        'Midland Regional Hospital Portlaoise',
#        'University Hospital Kerry', 'Cavan General Hospital',
#        'Mayo University Hospital', 'South Tipperary General Hospital',
#        'University Maternity Hospital Limerick',
#        'National Home Birth Services', 'National Maternity Hospital',
#        'University Maternity Hospital Limerick',
#        'St Luke’s General Hospital', 'Rotunda Hospital',
#        'University Hospital Kerry', 'University Hospital Waterford',
#        'University Hospital Waterford', 'Letterkenny University Hospital',
#        'Mayo University Hospital', 'South Tipperary General Hospital',
#        'Mayo University Hospital', 'St Luke’s General Hospital',
#        'Letterkenny University Hospital', 'St Luke’s General Hospital',
#        'University Hospital Waterford', 'National Maternity Hospital',
#        'Rotunda Hospital', 'National Maternity Hospital',
#        'Cavan General Hospital', 'University Hospital Kerry',
#        'Portiuncula University Hospital',
#        'South Tipperary General Hospital', 'Rotunda Hospital',
#        'Letterkenny University Hospital',
#        'Portiuncula University Hospital', 'Mayo University Hospital',
#        'South Tipperary General Hospital', 'National Maternity Hospital',
#        'Cavan General Hospital', 'South Tipperary General Hospital',
#        'Cavan General Hospital', 'Wexford General Hospital',
#        'Midland Regional Hospital Mullingar',
#        'Cork University Maternity Hospital',
#        'University Maternity Hospital Limerick', 'Cavan General Hospital',
#        'St Luke’s General Hospital', 'University Hospital Galway',
#        'Portiuncula University Hospital', 'Sligo University Hospital',
#        'University Hospital Kerry', 'Cork University Maternity Hospital',
#        'National Maternity Hospital', 'Wexford General Hospital',
#        'National Home Birth Services',
#        'Coombe Women and Infants University Hospital',
#        'Coombe Women and Infants University Hospital',
#        'Our Lady of Lourdes Hospital', 'Our Lady of Lourdes Hospital',
#        'Cavan General Hospital', 'Letterkenny University Hospital',
#        'National Maternity Hospital',
#        'Midland Regional Hospital Mullingar', 'Cavan General Hospital',
#        'University Hospital Galway', 'Portiuncula University Hospital',
#        'Cavan General Hospital', 'St Luke’s General Hospital',
#        'University Hospital Galway', 'University Hospital Waterford',
#        'Rotunda Hospital', 'University Hospital Kerry',
#        'Mayo University Hospital', 'National Home Birth Services',
#        'Wexford General Hospital', 'Wexford General Hospital',
#        'Our Lady of Lourdes Hospital', 'University Hospital Galway',
#        'University Hospital Kerry', 'National Maternity Hospital',
#        'South Tipperary General Hospital', 'St Luke’s General Hospital',
#        'Cork University Maternity Hospital', 'University Hospital Kerry',
#        'University Hospital Galway',
#        'Midland Regional Hospital Portlaoise',
#        'University Hospital Kerry', 'Our Lady of Lourdes Hospital',
#        'St Luke’s General Hospital', 'Cavan General Hospital',
#        'Midland Regional Hospital Portlaoise',
#        'Coombe Women and Infants University Hospital',
#        'University Hospital Kerry',
#        'University Maternity Hospital Limerick',
#        'University Hospital Waterford',
#        'Coombe Women and Infants University Hospital',
#        'Letterkenny University Hospital',
#        'Coombe Women and Infants University Hospital',
#        'University Hospital Waterford', 'Our Lady of Lourdes Hospital',
#        'National Home Birth Services',
#        'Cork University Maternity Hospital',
#        'Midland Regional Hospital Mullingar',
#        'South Tipperary General Hospital', 'Mayo University Hospital',
#        'University Maternity Hospital Limerick', 'Rotunda Hospital',
#        'Our Lady of Lourdes Hospital', 'Rotunda Hospital',
#        'National Home Birth Services',
#        'Cork University Maternity Hospital',
#        'Portiuncula University Hospital', 'Rotunda Hospital',
#        'Sligo University Hospital', 'Letterkenny University Hospital',
#        'Portiuncula University Hospital',
#        'Cork University Maternity Hospital', 'Sligo University Hospital',
#        'Cork University Maternity Hospital',
#        'Portiuncula University Hospital', 'St Luke’s General Hospital',
#        'St Luke’s General Hospital', 'St Luke’s General Hospital',
#        'Midland Regional Hospital Portlaoise',
#        'St Luke’s General Hospital', 'South Tipperary General Hospital',
#        'Our Lady of Lourdes Hospital', 'University Hospital Kerry',
#        'National Maternity Hospital', 'University Hospital Waterford',
#        'Our Lady of Lourdes Hospital', 'Cavan General Hospital',
#        'Letterkenny University Hospital',
#        'Letterkenny University Hospital', 'National Home Birth Services',
#        'National Maternity Hospital',
#        'Midland Regional Hospital Portlaoise',
#        'University Hospital Waterford', 'Portiuncula University Hospital',
#        'South Tipperary General Hospital',
#        'Portiuncula University Hospital',
#        'Cork University Maternity Hospital', 'St Luke’s General Hospital',
#        'Portiuncula University Hospital', 'University Hospital Galway',
#        'Midland Regional Hospital Portlaoise',
#        'Sligo University Hospital', 'South Tipperary General Hospital',
#        'South Tipperary General Hospital',
#        'Midland Regional Hospital Mullingar',
#        'Midland Regional Hospital Portlaoise',
#        'Portiuncula University Hospital', 'Rotunda Hospital',
#        'St Luke’s General Hospital', 'University Hospital Waterford',
#        'University Maternity Hospital Limerick',
#        'University Hospital Kerry', 'National Maternity Hospital',
#        'National Maternity Hospital', 'University Hospital Galway',
#        'Coombe Women and Infants University Hospital',
#        'Cork University Maternity Hospital', 'Wexford General Hospital',
#        'Midland Regional Hospital Mullingar', 'Cavan General Hospital',
#        'Portiuncula University Hospital', 'University Hospital Kerry',
#        'Sligo University Hospital',
#        'Coombe Women and Infants University Hospital',
#        'University Maternity Hospital Limerick',
#        'Cork University Maternity Hospital', 'Cavan General Hospital',
#        'Letterkenny University Hospital', 'National Maternity Hospital',
#        'National Maternity Hospital', 'University Hospital Kerry',
#        'Mayo University Hospital', 'Mayo University Hospital',
#        'National Maternity Hospital', 'Wexford General Hospital',
#        'St Luke’s General Hospital', 'Portiuncula University Hospital',
#        'University Hospital Kerry', 'South Tipperary General Hospital',
#        'Midland Regional Hospital Portlaoise',
#        'University Hospital Galway',
#        'Midland Regional Hospital Portlaoise', 'Cavan General Hospital',
#        'Cavan General Hospital', 'Letterkenny University Hospital',
#        'Midland Regional Hospital Portlaoise',
#        'University Hospital Waterford',
#        'Midland Regional Hospital Mullingar',
#        'Midland Regional Hospital Portlaoise',
#        'St Luke’s General Hospital', 'University Hospital Waterford',
#        'Sligo University Hospital', 'National Maternity Hospital',
#        'Letterkenny University Hospital',
#        'Portiuncula University Hospital',
#        'Midland Regional Hospital Mullingar',
#        'Coombe Women and Infants University Hospital',
#        'Coombe Women and Infants University Hospital',
#        'University Hospital Waterford', 'National Home Birth Services',
#        'National Home Birth Services', 'Portiuncula University Hospital',
#        'Midland Regional Hospital Mullingar',
#        'Our Lady of Lourdes Hospital', 'University Hospital Waterford',
#        'University Maternity Hospital Limerick',
#        'Portiuncula University Hospital',
#        'Midland Regional Hospital Portlaoise',
#        'St Luke’s General Hospital', 'Portiuncula University Hospital',
#        'St Luke’s General Hospital', 'University Hospital Galway',
#        'South Tipperary General Hospital', 'National Maternity Hospital',
#        'University Hospital Kerry', 'Cork University Maternity Hospital',
#        'University Hospital Galway', 'University Hospital Galway',
#        'St Luke’s General Hospital', 'University Hospital Kerry',
#        'South Tipperary General Hospital',
#        'University Hospital Waterford', 'Cavan General Hospital',
#        'University Hospital Kerry', 'Letterkenny University Hospital',
#        'Coombe Women and Infants University Hospital',
#        'South Tipperary General Hospital', 'University Hospital Galway',
#        'University Hospital Waterford',
#        'Coombe Women and Infants University Hospital',
#        'University Hospital Waterford',
#        'Midland Regional Hospital Portlaoise',
#        'National Maternity Hospital', 'South Tipperary General Hospital',
#        'Mayo University Hospital', 'Sligo University Hospital',
#        'University Maternity Hospital Limerick',
#        'University Maternity Hospital Limerick',
#        'Cork University Maternity Hospital', 'Wexford General Hospital',
#        'Midland Regional Hospital Mullingar',
#        'St Luke’s General Hospital', 'University Hospital Kerry',
#        'University Hospital Waterford', 'National Home Birth Services',
#        'Mayo University Hospital', 'Mayo University Hospital',
#        'National Home Birth Services', 'University Hospital Kerry',
#        'National Home Birth Services',
#        'Midland Regional Hospital Mullingar',
#        'National Maternity Hospital', 'Cavan General Hospital',
#        'Our Lady of Lourdes Hospital', 'Sligo University Hospital',
#        'University Hospital Kerry', 'Cork University Maternity Hospital',
#        'Letterkenny University Hospital', 'University Hospital Waterford',
#        'University Hospital Galway', 'Cavan General Hospital',
#        'Rotunda Hospital', 'Letterkenny University Hospital',
#        'University Hospital Galway', 'University Hospital Galway',
#        'Sligo University Hospital', 'Cavan General Hospital',
#        'Cork University Maternity Hospital', 'Rotunda Hospital',
#        'Rotunda Hospital', 'University Hospital Galway',
#        'Midland Regional Hospital Portlaoise',
#        'National Maternity Hospital', 'Rotunda Hospital',
#        'Mayo University Hospital', 'Wexford General Hospital',
#        'South Tipperary General Hospital',
#        'Letterkenny University Hospital', 'University Hospital Galway',
#        'University Maternity Hospital Limerick',
#        'University Hospital Waterford', 'University Hospital Galway',
#        'University Hospital Galway', 'Wexford General Hospital',
#        'University Hospital Kerry', 'Sligo University Hospital',
#        'Cork University Maternity Hospital', 'St Luke’s General Hospital',
#        'Letterkenny University Hospital',
#        'Coombe Women and Infants University Hospital',
#        'Portiuncula University Hospital', 'Rotunda Hospital',
#        'Rotunda Hospital', 'Wexford General Hospital',
#        'Cork University Maternity Hospital',
#        'Letterkenny University Hospital', 'Wexford General Hospital',
#        'Cavan General Hospital', 'National Maternity Hospital',
#        'Rotunda Hospital', 'University Maternity Hospital Limerick',
#        'University Maternity Hospital Limerick',
#        'St Luke’s General Hospital',
#        'Midland Regional Hospital Portlaoise',
#        'University Maternity Hospital Limerick',
#        'University Maternity Hospital Limerick',
#        'University Hospital Kerry', 'National Home Birth Services',
#        'Letterkenny University Hospital',
#        'Cork University Maternity Hospital', 'Rotunda Hospital',
#        'Coombe Women and Infants University Hospital',
#        'University Hospital Galway', 'University Hospital Waterford',
#        'Sligo University Hospital', 'Our Lady of Lourdes Hospital',
#        'National Home Birth Services', 'University Hospital Kerry',
#        'South Tipperary General Hospital',
#        'Midland Regional Hospital Portlaoise',
#        'University Hospital Waterford', 'Mayo University Hospital',
#        'Sligo University Hospital', 'South Tipperary General Hospital',
#        'Cork University Maternity Hospital',
#        'Coombe Women and Infants University Hospital',
#        'National Maternity Hospital', 'South Tipperary General Hospital',
#        'University Hospital Galway', 'Letterkenny University Hospital',
#        'Mayo University Hospital', 'Sligo University Hospital',
#        'Midland Regional Hospital Mullingar',
#        'Midland Regional Hospital Portlaoise',
#        'National Maternity Hospital', 'University Hospital Galway',
#        'University Hospital Waterford',
#        'Cork University Maternity Hospital',
#        'University Hospital Waterford', 'Sligo University Hospital',
#        'South Tipperary General Hospital', 'National Home Birth Services',
#        'Wexford General Hospital',
#        'Coombe Women and Infants University Hospital',
#        'Letterkenny University Hospital',
#        'Portiuncula University Hospital',
#        'Cork University Maternity Hospital', 'Mayo University Hospital',
#        'Midland Regional Hospital Portlaoise', 'Mayo University Hospital',
#        'Coombe Women and Infants University Hospital',
#        'University Hospital Waterford',
#        'Cork University Maternity Hospital', 'Wexford General Hospital',
#        'Sligo University Hospital',
#        'Coombe Women and Infants University Hospital',
#        'Cork University Maternity Hospital',
#        'Midland Regional Hospital Mullingar',
#        'St Luke’s General Hospital', 'National Home Birth Services',
#        'Midland Regional Hospital Mullingar',
#        'National Home Birth Services',
#        'Coombe Women and Infants University Hospital', 'Rotunda Hospital',
#        'University Maternity Hospital Limerick',
#        'Midland Regional Hospital Mullingar',
#        'University Maternity Hospital Limerick', 'Cavan General Hospital',
#        'University Hospital Galway', 'University Hospital Kerry',
#        'Portiuncula University Hospital', 'National Maternity Hospital',
#        'Letterkenny University Hospital', 'St Luke’s General Hospital',
#        'Letterkenny University Hospital', 'University Hospital Kerry',
#        'Letterkenny University Hospital', 'Mayo University Hospital',
#        'Portiuncula University Hospital',
#        'Letterkenny University Hospital',
#        'Midland Regional Hospital Portlaoise',
#        'Our Lady of Lourdes Hospital', 'Mayo University Hospital',
#        'Mayo University Hospital',
#        'University Maternity Hospital Limerick'], dtype='<U44')

# %%
#Plot the Hospitals using a histogram to visualize the distribution of this variable
# Histogram

plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(Hospitals, bins=10)
plt.xlabel('Hospitals')
plt.show()

# %% [markdown]
# ### Variable 4 : HospitalFeedingSupport

# %%
HospitalFeedingSupport=np.random.randint(10,size=(500))
HospitalFeedingSupport
# Out:
# array([9, 7, 5, 2, 1, 2, 5, 9, 0, 7, 7, 6, 9, 5, 1, 2, 4, 5, 2, 1, 1, 4,
#        6, 8, 5, 8, 9, 0, 4, 4, 2, 3, 7, 5, 5, 8, 2, 7, 1, 5, 0, 5, 7, 9,
#        4, 3, 0, 9, 9, 7, 2, 6, 5, 8, 8, 6, 5, 1, 6, 9, 5, 6, 4, 6, 2, 9,
#        5, 6, 6, 0, 9, 7, 4, 7, 7, 3, 1, 9, 3, 5, 2, 7, 7, 8, 1, 3, 2, 1,
#        8, 9, 5, 4, 0, 7, 7, 0, 3, 5, 1, 3, 5, 3, 2, 5, 9, 5, 2, 5, 5, 0,
#        7, 7, 9, 8, 4, 0, 9, 4, 1, 0, 1, 5, 7, 1, 3, 3, 5, 9, 2, 2, 0, 9,
#        2, 6, 1, 2, 5, 3, 9, 1, 3, 3, 7, 0, 1, 0, 9, 1, 6, 3, 9, 6, 3, 7,
#        6, 3, 8, 8, 1, 0, 6, 9, 1, 6, 6, 8, 7, 3, 1, 9, 4, 0, 4, 9, 9, 7,
#        7, 8, 5, 9, 6, 0, 9, 7, 8, 1, 1, 1, 3, 7, 6, 1, 2, 9, 7, 8, 6, 7,
#        4, 9, 7, 5, 2, 3, 1, 0, 8, 6, 6, 2, 7, 4, 3, 4, 1, 6, 6, 1, 8, 9,
#        9, 3, 6, 0, 9, 1, 7, 2, 7, 7, 0, 2, 4, 4, 3, 5, 7, 6, 4, 8, 5, 2,
#        6, 6, 3, 8, 9, 5, 9, 6, 3, 5, 3, 0, 8, 2, 1, 6, 8, 5, 4, 9, 3, 3,
#        8, 5, 5, 8, 8, 2, 0, 1, 2, 1, 4, 6, 4, 1, 4, 6, 9, 3, 2, 7, 0, 3,
#        4, 6, 4, 4, 8, 4, 7, 4, 2, 5, 5, 6, 5, 4, 1, 3, 6, 7, 9, 8, 0, 0,
#        5, 8, 9, 9, 9, 0, 3, 5, 9, 3, 7, 3, 2, 4, 9, 5, 7, 6, 5, 4, 7, 9,
#        1, 8, 4, 3, 2, 0, 0, 3, 2, 3, 7, 4, 8, 2, 5, 4, 8, 6, 3, 5, 6, 8,
#        9, 0, 6, 3, 1, 0, 8, 8, 2, 8, 5, 4, 4, 2, 7, 7, 7, 2, 8, 7, 6, 9,
#        0, 0, 5, 5, 7, 9, 9, 3, 0, 4, 7, 7, 8, 1, 8, 6, 2, 7, 4, 4, 3, 2,
#        5, 7, 2, 9, 7, 4, 0, 3, 9, 6, 1, 2, 9, 3, 5, 0, 6, 7, 9, 5, 1, 6,
#        7, 8, 2, 4, 6, 9, 6, 6, 0, 2, 8, 8, 7, 0, 5, 7, 8, 2, 4, 1, 3, 2,
#        6, 8, 9, 0, 2, 6, 1, 9, 4, 1, 5, 9, 7, 0, 4, 7, 3, 5, 1, 3, 0, 1,
#        7, 2, 3, 1, 7, 7, 5, 6, 0, 5, 8, 9, 9, 8, 1, 9, 5, 3, 6, 3, 7, 9,
#        5, 6, 7, 2, 8, 0, 8, 1, 0, 2, 4, 6, 3, 6, 5, 0])

# %%
#Plot the HospitalFeedingSupport using a histogram to visualize the distribution of this variable
# Histogram

plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(HospitalFeedingSupport, bins=10)
plt.xlabel('HospitalFeedingSupport')
plt.show()

# %% [markdown]
# ### Variable 5 : HomeFeedingSupport

# %%
HomeFeedingSupport=np.random.randint(10,size=(500))
HomeFeedingSupport
# Out:
# array([2, 6, 6, 2, 3, 5, 5, 0, 4, 8, 5, 0, 9, 3, 1, 3, 4, 4, 7, 5, 7, 1,
#        3, 5, 0, 4, 9, 4, 9, 0, 6, 3, 6, 2, 8, 6, 9, 0, 7, 4, 4, 0, 6, 4,
#        4, 7, 7, 3, 4, 9, 2, 7, 7, 4, 3, 9, 3, 8, 9, 7, 8, 9, 8, 0, 4, 6,
#        9, 8, 7, 3, 2, 4, 3, 7, 9, 6, 3, 7, 1, 1, 0, 6, 6, 8, 4, 9, 5, 6,
#        9, 2, 1, 0, 8, 4, 3, 5, 6, 3, 1, 2, 5, 0, 1, 6, 1, 7, 8, 4, 6, 0,
#        8, 2, 4, 2, 8, 1, 9, 4, 4, 6, 1, 5, 4, 3, 5, 3, 3, 1, 3, 6, 5, 3,
#        7, 2, 0, 3, 3, 4, 6, 6, 7, 9, 3, 4, 2, 7, 8, 6, 8, 7, 8, 1, 9, 7,
#        1, 0, 5, 2, 7, 0, 6, 9, 8, 1, 5, 3, 2, 3, 0, 4, 6, 7, 9, 3, 6, 2,
#        3, 2, 8, 6, 1, 5, 6, 6, 4, 1, 7, 9, 9, 8, 9, 6, 1, 8, 2, 2, 0, 2,
#        3, 9, 9, 7, 8, 3, 1, 2, 4, 7, 7, 4, 7, 5, 3, 6, 9, 7, 5, 7, 7, 1,
#        7, 1, 9, 2, 6, 1, 5, 5, 9, 1, 5, 0, 1, 6, 2, 4, 7, 5, 2, 5, 1, 2,
#        6, 1, 5, 5, 8, 9, 4, 9, 9, 1, 9, 3, 7, 0, 7, 9, 9, 5, 5, 3, 6, 2,
#        2, 5, 5, 9, 4, 7, 9, 4, 9, 1, 4, 9, 0, 6, 8, 1, 1, 6, 5, 2, 6, 5,
#        8, 9, 8, 6, 7, 0, 8, 0, 6, 4, 7, 4, 3, 9, 0, 8, 5, 4, 1, 6, 4, 7,
#        9, 3, 5, 8, 2, 7, 9, 3, 5, 1, 0, 0, 1, 3, 5, 6, 2, 3, 7, 4, 2, 1,
#        5, 7, 5, 1, 5, 1, 4, 5, 4, 7, 4, 6, 1, 8, 3, 4, 8, 3, 7, 4, 8, 3,
#        0, 3, 7, 5, 2, 4, 0, 2, 9, 8, 3, 6, 7, 7, 7, 0, 0, 0, 9, 6, 2, 8,
#        9, 5, 7, 7, 3, 1, 5, 3, 9, 2, 6, 4, 1, 4, 0, 2, 1, 8, 6, 9, 0, 4,
#        2, 1, 0, 4, 5, 3, 1, 1, 2, 4, 3, 6, 1, 0, 9, 9, 7, 8, 1, 3, 7, 5,
#        9, 0, 2, 1, 7, 9, 6, 6, 2, 3, 8, 0, 9, 5, 1, 2, 2, 0, 8, 0, 5, 4,
#        1, 5, 7, 3, 1, 6, 3, 3, 6, 2, 3, 1, 6, 5, 2, 3, 3, 4, 6, 8, 9, 9,
#        4, 0, 7, 4, 0, 8, 9, 5, 1, 9, 2, 9, 2, 4, 5, 3, 1, 3, 2, 9, 6, 2,
#        8, 4, 4, 7, 8, 2, 1, 9, 7, 3, 0, 1, 1, 2, 5, 3])

# %%
plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(HomeFeedingSupport, bins=10)
plt.xlabel('HomeFeedingSupport')
plt.show()

# %% [markdown]
# ### Variable 6 : FeedingDecisionRespected

# %%
FeedingDecisionRespected=np.random.randint(10, size=(500))
FeedingDecisionRespected
# Out:
# array([9, 7, 5, 3, 7, 0, 7, 4, 8, 1, 8, 3, 2, 0, 3, 4, 1, 3, 4, 2, 1, 6,
#        9, 3, 9, 5, 3, 4, 6, 4, 3, 9, 8, 1, 8, 0, 1, 7, 8, 6, 4, 2, 5, 4,
#        1, 6, 0, 4, 5, 4, 4, 3, 5, 9, 3, 9, 7, 3, 1, 1, 0, 1, 4, 9, 9, 8,
#        2, 1, 7, 2, 9, 6, 2, 5, 3, 3, 4, 4, 9, 7, 7, 5, 5, 0, 7, 6, 8, 5,
#        7, 0, 9, 2, 9, 3, 1, 9, 2, 9, 1, 4, 6, 7, 7, 6, 3, 3, 5, 0, 3, 2,
#        7, 8, 5, 3, 4, 0, 8, 5, 1, 0, 9, 0, 5, 1, 7, 0, 5, 6, 7, 4, 7, 5,
#        0, 1, 8, 8, 0, 8, 1, 0, 7, 0, 5, 0, 1, 7, 6, 5, 2, 0, 5, 3, 5, 5,
#        2, 6, 1, 2, 4, 7, 0, 3, 6, 4, 5, 7, 9, 7, 2, 3, 3, 4, 7, 9, 9, 4,
#        5, 2, 3, 4, 6, 6, 5, 1, 8, 1, 7, 0, 2, 2, 7, 6, 5, 0, 4, 6, 9, 9,
#        4, 7, 6, 4, 1, 7, 7, 2, 3, 7, 3, 7, 0, 2, 1, 0, 0, 7, 8, 4, 1, 6,
#        6, 1, 8, 8, 5, 7, 3, 1, 0, 8, 2, 9, 7, 7, 8, 7, 2, 6, 7, 6, 5, 5,
#        3, 2, 5, 7, 9, 6, 7, 1, 6, 9, 2, 7, 5, 5, 5, 5, 6, 1, 6, 2, 7, 4,
#        2, 4, 6, 6, 9, 5, 7, 5, 1, 1, 2, 4, 2, 5, 7, 7, 5, 8, 1, 8, 0, 3,
#        4, 8, 6, 5, 2, 3, 7, 3, 9, 4, 4, 7, 7, 8, 1, 2, 3, 7, 4, 1, 2, 9,
#        1, 0, 8, 3, 1, 9, 3, 7, 6, 4, 0, 9, 1, 3, 0, 5, 1, 5, 3, 1, 8, 1,
#        8, 9, 6, 9, 7, 4, 6, 1, 5, 1, 9, 9, 8, 8, 1, 2, 6, 1, 7, 6, 0, 3,
#        0, 7, 6, 9, 1, 8, 0, 4, 9, 7, 4, 3, 3, 3, 7, 0, 2, 2, 3, 8, 3, 9,
#        5, 8, 6, 7, 2, 1, 4, 9, 1, 7, 6, 1, 1, 9, 6, 2, 7, 6, 9, 5, 2, 6,
#        9, 8, 5, 5, 8, 3, 4, 8, 5, 5, 5, 5, 3, 4, 9, 5, 5, 9, 1, 6, 8, 4,
#        2, 2, 0, 6, 4, 1, 6, 4, 1, 4, 0, 7, 9, 9, 8, 6, 5, 3, 7, 5, 4, 7,
#        8, 6, 6, 9, 4, 1, 1, 9, 3, 7, 2, 9, 7, 3, 5, 1, 5, 5, 2, 6, 3, 0,
#        1, 8, 6, 6, 0, 7, 6, 2, 9, 4, 7, 3, 3, 8, 7, 2, 5, 5, 4, 2, 3, 7,
#        5, 7, 4, 6, 6, 0, 3, 1, 5, 8, 6, 4, 3, 1, 4, 7])

# %%
plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist( FeedingDecisionRespected, bins=10)
plt.xlabel(' FeedingDecisionRespected')
plt.show()

# %% [markdown]
# ### Variable 7 : Breastfeeding- 6months

# %%
Breastfeeding6months=np.random.randint(10, size=(500)) 
Breastfeeding6months
# Out:
# array([2, 9, 9, 8, 4, 6, 2, 1, 8, 4, 8, 1, 1, 4, 5, 1, 7, 6, 4, 7, 5, 7,
#        9, 7, 8, 3, 5, 1, 3, 4, 5, 6, 9, 2, 5, 2, 2, 6, 7, 7, 4, 4, 8, 1,
#        0, 9, 8, 9, 8, 7, 1, 0, 2, 0, 0, 2, 3, 3, 8, 8, 8, 4, 1, 4, 8, 4,
#        3, 4, 9, 9, 3, 6, 3, 9, 0, 5, 5, 6, 2, 5, 3, 4, 6, 9, 5, 6, 1, 4,
#        3, 7, 4, 5, 7, 8, 0, 9, 6, 9, 9, 9, 7, 5, 3, 4, 2, 2, 6, 3, 6, 8,
#        9, 8, 8, 9, 0, 0, 7, 7, 5, 7, 0, 9, 2, 1, 4, 4, 5, 0, 7, 2, 8, 2,
#        4, 9, 6, 5, 2, 2, 5, 1, 5, 2, 7, 3, 4, 7, 4, 2, 6, 2, 4, 8, 7, 2,
#        6, 7, 6, 3, 9, 9, 1, 0, 5, 3, 0, 2, 3, 0, 2, 0, 3, 0, 0, 5, 4, 6,
#        9, 7, 5, 9, 0, 2, 7, 2, 7, 6, 8, 4, 0, 5, 7, 0, 6, 4, 1, 9, 2, 6,
#        5, 5, 8, 6, 6, 7, 5, 4, 1, 9, 8, 7, 9, 8, 3, 4, 2, 4, 3, 6, 6, 0,
#        6, 2, 8, 9, 4, 0, 7, 2, 9, 7, 6, 7, 3, 9, 2, 1, 8, 1, 5, 9, 3, 1,
#        6, 7, 6, 1, 2, 1, 0, 6, 3, 0, 8, 7, 4, 0, 2, 9, 3, 9, 5, 7, 9, 5,
#        9, 1, 5, 2, 2, 0, 1, 9, 4, 2, 2, 0, 7, 8, 2, 4, 4, 8, 8, 9, 2, 0,
#        3, 7, 0, 8, 8, 2, 9, 3, 0, 1, 4, 2, 4, 3, 1, 5, 2, 9, 3, 7, 2, 6,
#        3, 6, 2, 1, 0, 3, 0, 5, 5, 9, 5, 8, 2, 2, 0, 6, 4, 8, 5, 5, 8, 1,
#        3, 4, 9, 0, 2, 0, 3, 1, 2, 7, 5, 9, 1, 4, 1, 5, 0, 8, 2, 3, 0, 9,
#        8, 0, 6, 2, 1, 6, 3, 8, 4, 7, 5, 2, 6, 2, 9, 6, 0, 8, 0, 5, 9, 2,
#        7, 9, 2, 8, 0, 3, 0, 7, 4, 9, 3, 9, 8, 7, 3, 3, 5, 3, 8, 4, 8, 8,
#        2, 8, 3, 9, 4, 9, 6, 3, 8, 7, 8, 3, 2, 6, 6, 3, 0, 8, 6, 1, 2, 6,
#        6, 5, 6, 3, 7, 7, 7, 4, 4, 0, 9, 4, 7, 2, 3, 9, 5, 0, 6, 5, 1, 6,
#        9, 6, 8, 3, 2, 8, 7, 9, 2, 6, 6, 4, 6, 5, 5, 2, 6, 9, 6, 6, 2, 5,
#        8, 3, 7, 2, 1, 8, 0, 5, 3, 9, 1, 5, 7, 6, 6, 7, 8, 5, 9, 9, 5, 6,
#        6, 4, 5, 4, 5, 9, 8, 6, 7, 9, 9, 2, 6, 3, 8, 8])

# %%
plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist( Breastfeeding6months, bins=10)
plt.xlabel(' Breastfeeding6months')
plt.show()

# %% [markdown]
# ### Dataframe containing all data generated

# %%
df=pd.DataFrame(data={'AgeProfile': AgeProfile, 'Ethnicity': Ethnicity, 'FeedingChoices': FeedingChoices, 'Hospitals':Hospitals, 'HospitalFeedingSupport':HospitalFeedingSupport, 'HomeFeedingSupport':HomeFeedingSupport, 'FeedingDecisionRespected':FeedingDecisionRespected})

# Add a column named Breastfeeding6months - if the BMI is less than 30 kg/m2 the woman is classified as overweight, otherwise is classified as obese.

df['Breastfeeding6months'] = np.where(df['FeedingChoices'] < 30,'Overweight','Obese')

# Check the first 20 rows of the dataframe
df.head(20)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 


#Create the Age profile
AgeProfile = [20,25,30,35,40 ]

#Create the Hospitals
Hospitals = ['National Maternity Hospital',
             'Coombe Women and Infants University Hospital',
             'Cork University Maternity Hospital',
             'University Maternity Hospital Limerick',
             'Our Lady of Lourdes Hospital',
             'University Hospital Galway',
             'Cavan General Hospital',
             'Letterkenny University Hospital',
             'Mayo University Hospital',
             'Midland Regional Hospital Mullingar',
             'Midland Regional Hospital Portlaoise',
             'Portiuncula University Hospital',
             'Sligo University Hospital',
             'South Tipperary General Hospital',
             'St Luke’s General Hospital',
             'University Hospital Kerry',
             'University Hospital Waterford',
             'Wexford General Hospital',
             'National Home Birth Services',
             'Rotunda Hospital']

#Support offered in Hospital

#Ethnic Characteristic of women who responded to the survey

Ethnicity= ['White Irish','Roma','African','Chinese','Arabic','Asian','Mixed','Other']

#Create the feeding options
FeedingChoices = ['Breast milk','breast /formula milk Combo','Formula (bottle) milk','Don’t know or can’t remember' ]

#Create the dataframe with column headings
df = pd.DataFrame(columns=[ 'AgeProfile','Ethnicity', 'Hospitals','HospitalFeedingSupport', 'HomeFeedingSupport', 'FeedingChoices','FeedingDecisionRespected'])
                   
#Populate the Age Profile column 
df['AgeProfile'] = np.random.choice(AgeProfile, 500, p=[0.048, 0.141, 0.366,0.358,0.087]) 

#Populate the Ethnicity column 
df['Ethnicity'] = np.random.choice(Ethnicity, 500, p=[0.939,0.003,0.014,0.004,0.004,0.017,0.01,0.009]) 
                   
 #Populate the dataframe with results according to actual probabilities inferred from Survey
df['Hospitals'] = np.random.choice(Hospitals, 500, p=[0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.04, 0.05, 0.05, 0.04, 0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05])                  
 #Populate the dataframe with results according to actual probabilities inferred from Survey
    
df['FeedingChoices'] = np.random.choice(FeedingChoices, 500, p=[0.4,0.3,0.29,0.01])                                       

df['HospitalFeedingSupport']=np.random.randint(10,size=(500))
    
df['HomeFeedingSupport']=np.random.randint(10,size=(500))   

df['FeedingDecisionRespected']=np.random.randint(10, size=(500)) 

df['Breastfeeding6months']=np.random.randint(10, size=(500)) 


import seaborn as sns

display(df) 
df.describe()

plt.hist(df['AgeProfile'],bins=10, color='green')
plt.title('AgeProfile', fontsize=14)
plt.xlabel('AgeProfile', fontsize=14)
plt.show()

#sns.displot(df, x="AgeProfile", y = "FeedingChoices",multiple="stack", binwidth=3)

#sns.displot(df,x="AgeProfile",hue="FeedingChoices", col="HomeFeedingSupport", kind="kde")


#sns.displot(df,x="AgeProfile",hue="FeedingChoices", col="HospitalFeedingSupport", kind="kde")

sns.displot(data=df, x="AgeProfile", hue="FeedingChoices", kind="kde")
sns.displot(data=df, x="HomeFeedingSupport", hue="FeedingChoices", kind="kde")
sns.displot(data=df, x="HospitalFeedingSupport", hue="FeedingChoices", kind="kde")
# Out:
#      AgeProfile    Ethnicity                               Hospitals  \
# 0            35  White Irish            Our Lady of Lourdes Hospital
# 1            30  White Irish        South Tipperary General Hospital
# 2            35  White Irish  University Maternity Hospital Limerick
# 3            35  White Irish             National Maternity Hospital
# 4            25  White Irish           University Hospital Waterford
# ..          ...          ...                                     ...
# 495          30  White Irish              University Hospital Galway
# 496          35  White Irish             National Maternity Hospital
# 497          35  White Irish                  Cavan General Hospital
# 498          25  White Irish            National Home Birth Services
# 499          30  White Irish            Our Lady of Lourdes Hospital
#
#      HospitalFeedingSupport  HomeFeedingSupport              FeedingChoices  \
# 0                         9                   2       Formula (bottle) milk
# 1                         9                   3  breast /formula milk Combo
# 2                         4                   6                 Breast milk
# 3                         6                   4  breast /formula milk Combo
# 4                         1                   2  breast /formula milk Combo
# ..                      ...                 ...                         ...
# 495                       4                   8  breast /formula milk Combo
# 496                       7                   4       Formula (bottle) milk
# 497                       7                   1       Formula (bottle) milk
# 498                       8                   4                 Breast milk
# 499                       3                   2       Formula (bottle) milk
#
#      FeedingDecisionRespected  Breastfeeding6months
# 0                           2                     5
# 1                           1                     4
# 2                           5                     8
# 3                           5                     0
# 4                           9                     0
# ..                        ...                   ...
# 495                         7                     1
# 496                         1                     6
# 497                         9                     1
# 498                         0                     3
# 499                         5                     7
#
# [500 rows x 8 columns]
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### References
# [] https://yourexperience.ie/wp-content/uploads/2020/09/National-Maternity-Experience-Survey-results.pdf
# [ ] https://www.irishexaminer.com/news/arid-30812126.html#:~:text=The%20average%20age%20Irish%20women,first%20baby%20is%2032.5%20years.- Average age for mothers in ireland
# [] https://jech.bmj.com/content/68/4/356 - Ethnicity and Breastfeeding in Ireland
# [] https://www.hse.ie/eng/about/who/healthwellbeing/our-priority-programmes/child-health-and-wellbeing/breastfeeding-healthy-childhood-programme/policies-and-guidelines-breastfeeding/breastfeeding-in-a-healthy-ireland-report.pdf
