# %% [markdown]
# ## Project 2020
# ### Programming for Data Analysis
#
# ### Project 2020  Feeding Choices and supports for Irish Mothers 2019
#
# ### Aim:
#
# - Choose a real-world phenomenon that can be measured - gather 100 datapoints across 4 variables
# - Investigate the types of variables involved , their likely distributions and relationships with each other
# - Simulate a Dataset as closely matching their properties as possible
# - Detail your research and implement the simulation in a jupyter notebook
# - Create a git repository

# %% [markdown]
# #### Introduction [1]
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# The real-world phenonmenon I have choosen is the topic of feeding babies and the options , support given to mothers in ireland. The reference point is the National Maternity Experience Survey.
# Women age 16 and over who gave birth in October/November of 2019 and was also resident of Ireland took part in  survey .A total of 3,204 women was surveyed in 19 participating maternity hospitals/units and home birth services. There was 6 topics covered and one of them was Feeding where the result was 7.8 out of 10 response. This section was highlighted as an area of needed improvement. This topic is personal to me as I myself am a new mother.
#
# Using the real-life percentage results from this section of the survey , I am going simulate/ create a dataset to show results of the types of feeding and the level of support. I would like to see if there is a relationship between the level of support and the choice of feeding selected by the new mothers in the first few days.
#
# List of Hospitals Taking part :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The distributions and relationships between the variables[1,2,3,4]
#
# #### Investigate the types of variables involved, their likely distributions, and their relationships with each other.
#
# Using the National Maternity Experience Survey as a reference , I reviewed the sections covered and the questions asked. One of the lowest scoring questions were based on Feeding and support. 15% of women said that while they were in the hospital they did not get adequate support or encouragement with feeding their baby. By Feeding , I mean breastfeeding mainly but will look at all other forms as well.  There is room for improvement here. Historicall , brestfeeding rates in ireland have been low compared with international averages.
#
# I decided to simulate a dataset containing results for the following variables and their influence on feeding choices especially breastfeeding for 500 new mothers.
#
# From the questions asked and answers , I choose the following a variables, trying to keep in line with the characteristics and  variables of the survey but changing if necessary to suit the purposes of simulating data. I also simulate the results in line with the survey results for each variable. For following variables , I will look at their impact on feeding especially breastfeeding :
#
#  - **AgeProfile** - ages <25, 25-30,30-35,35-40,<40
#
#  To have a good age range in order to examine if age has any impact on feeding choices.
#
#  - **Ethnicity** - White Irish','Roma','African','Chinese','Arabic','Asian','Mixed','Other'
#
#  Question asked : Has Ethnicity any impact on feeding choices ?
#
#  According to research , ethnicity does influence on breastfeeding initiation and duration. Looking at research results from 2019 , 55.9% ( 6202 out of 11,092) women initiated breastfeeding with only 7.9% continued breastfeeding until 9 months. However only 50% of Irish citizens (4693 of 9368) initiated breastfeeding compared to 88.7% of non-irish citizens ( 1503/1695).
#
#  - **Hospitals** - 19 hospitals and home birth services
#
#  Does the level of feeding support for mothers differ between the hospitals ?
#
#  - **HospitalFeedingSupport** - a score rating from 0- 5
#
#  During the mothers stay in hospital , did the healthcare professionals give adequate support and encouragement with feeding your baby ? Did this support influence your decision on the type of feeding you choose ?
#
#  - **HomeFeedingSupport**- a score rating from 0- 5
#
#  Once the mother was at home , did the healthcare professionals give adequate support and encouragement with feeding your baby ? Did this support influence your decision to continue or change your feeding choice ?
#
#  - **FeedingChoices**- Breast Milk,breast /Formula milk Combo,Formula (bottle) milk ( Artifical)
#
#  These are the feeding choices available and were initiated in the first week
#
#
#  - **Breastfeeding6months**  - Yes/No
#   Yes/ No are converted in to numbers for the purpose of analytic measurement
#   Yes = 1
#   No =  2
#   Did the mothers who choose breastfeeding continue to at least 6 months ?

# %% [markdown]
# ### Variable 1 : AGE PROFILE
#
# Generate random values of age using Numpy.random function

# %%
# Generate age between 20 and 45 years old using the Percent probabilities from survey
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set()

np.random.seed(42)

AgeProfile =20,25,30,35,40
AgeProfile = np.random.choice(AgeProfile, 500, p=[0.048, 0.141, 0.366, 0.358, 0.087]) 
AgeProfile

# %%
# Average age of the sample
import numpy as np
np.mean(AgeProfile)

# %% [markdown]
# #### The mean age is 31.22  which is in line the national average of 32.5 years

# %%
#Plot the age using a histogram to visualize the distribution of this variable
# Histogram

plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
bins=np.linspace (20,45,50) #linspace returns evenly spaced numbers over a specified interval
plt.hist(AgeProfile, bins)# adding distribution samples 
plt.xlabel('Age in years')
plt.ylabel('Frequency')
plt.title('Age of Mothers who took the Survey')

plt.show()

# %%
#Boxplot
import matplotlib.pyplot as plt
plt.boxplot(AgeProfile, showmeans=True)
plt.show()

# %% [markdown]
# ##### From the histogram above , we can see the peak ages for women is between 30 and 35. Also that the distribution is a normal , as from the boxplot , shows the mean and median are similar

# %% [markdown]
# ### Variable 2 : Ethnicity
#
# Assigning ethnicity randomly to the 500 mothers using Numpy.random function

# %%
#For analytic purposes , I convert each ethnic catergory into integers, these can be converted by to strings later
# 1= White Irish ,2= Roma, 3= African, 4 = Asian, 5 = Arabic, 6 = Mixed , 7 = Other

Ethnicity= ['1','2','3','4','5','6','7']
np.random.seed(42)
#Populate the Ethnicity column 
Ethnicity= np.random.choice(Ethnicity, 500, p=[0.903,0.003,0.014,0.057,0.004,0.01,0.009]) 
Ethnicity

# %%
#Plot the Ethniticy using a histogram to visualize the distribution of this variable
# Histogram
plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(Ethnicity, bins)
plt.xlabel('Ethnicity')
bins = np.linspace(0, 8, 10) # linspace returns evenly spaced numbers over a specified interval
plt.ylabel('Frequency') # labelling y axis
plt.title('Ethnicity') # Adding title

plt.show()

# %% [markdown]
# Its obvious that the distribution of the variable Ethnicity is not a normal one. The majority ethnic group is white irish mothers surveyed.

# %% [markdown]
# ### Variable 3 : FeedingChoices

# %%
import numpy as np
np.random.seed(42)
#1= Breast,#2= Combined,#3 = Formula
FeedingChoices= ['1','2','3']
#FeedingChoices = ['Breast','Combined','Formula' ]
FeedingChoices = np.random.choice(FeedingChoices, 500, p=[0.5,0.2,0.3])   
FeedingChoices

# %%
#Plot the FeedingChoices using a histogram to visualize the distribution of this variable
# Histogram
plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(FeedingChoices, bins=10)
plt.xlabel('FeedingChoices')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Variable 4 : Hospitals

# %%
import numpy as np
Hospitals = ['National Maternity Hospital',
             'Coombe Women and Infants University Hospital',
             'Cork University Maternity Hospital',
             'University Maternity Hospital Limerick',
             'Our Lady of Lourdes Hospital',
             'University Hospital Galway',
             'Cavan General Hospital',
             'Letterkenny University Hospital',
             'Mayo University Hospital',
             'Midland Regional Hospital Mullingar',
             'Midland Regional Hospital Portlaoise',
             'Portiuncula University Hospital',
             'Sligo University Hospital',
             'South Tipperary General Hospital',
             'St Luke’s General Hospital',
             'University Hospital Kerry',
             'University Hospital Waterford',
             'Wexford General Hospital',
             'National Home Birth Services',
             'Rotunda Hospital']

np.random.seed(42)
Hospitals = np.random.choice(Hospitals, 500, p=[0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.04, 0.05, 0.05, 0.04, 0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05])     
Hospitals

# %%
#Plot the Hospitals using a histogram to visualize the distribution of this variable
# Histogram

plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(Hospitals, bins=10)
plt.xlabel('Hospitals')
plt.show()

# %% [markdown]
# ### Variable 4 : HospitalFeedingSupport

# %%
np.random.seed(42)
HospitalFeedingSupport = [5,5,4,3,2]
HospitalFeedingSupport=np.random.choice(HospitalFeedingSupport, 500, p=[0.49,0.2,0.29,0.01,0.01]) 
HospitalFeedingSupport

# %%
#Plot the HospitalFeedingSupport using a histogram to visualize the distribution of this variable
# Histogram

plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(HospitalFeedingSupport, bins=10)
plt.xlabel('HospitalFeedingSupport')
plt.show()

# %% [markdown]
# ### Variable 5 : HomeFeedingSupport

# %%
np.random.seed(42)
HomeFeedingSupport=np.random.randint(6,size=(500)) 
HomeFeedingSupport

# %%
plt.figure(figsize=(12,8), facecolor='w', edgecolor='k', clear='True')
plt.hist(HomeFeedingSupport, bins=10)
plt.xlabel('HomeFeedingSupport')
plt.show()

# %% [markdown]
# ### Dataframe containing all data generated [5,6,7,8,9]

# %%
import pandas as pd
import numpy as np

# Adding survey variables to the dataframe:
HospitalFeedingSupport = [5,5,4,3,2]
HomeFeedingSupport = [5,5,4,3,3]
AgeProfile = [20,25,30,35,40 ]
Hospitals = ['National Maternity Hospital',
             'Coombe Women and Infants University Hospital',
             'Cork University Maternity Hospital',
             'University Maternity Hospital Limerick',
             'Our Lady of Lourdes Hospital',
             'University Hospital Galway',
             'Cavan General Hospital',
             'Letterkenny University Hospital',
             'Mayo University Hospital',
             'Midland Regional Hospital Mullingar',
             'Midland Regional Hospital Portlaoise',
             'Portiuncula University Hospital',
             'Sligo University Hospital',
             'South Tipperary General Hospital',
             'St Luke’s General Hospital',
             'University Hospital Kerry',
             'University Hospital Waterford',
             'Wexford General Hospital',
             'National Home Birth Services',
             'Rotunda Hospital']


#Ethnic Characteristic of women who responded to the survey
#1= White Irish ,2= Roma, 3= African, 4 = Asian, 5 = Arabic, 6 = Mixed , 7 = Other
Ethnicity= ['1','2','3','4','5','6','7']


#Create the feeding options
# 1 =Breastmilk,2 =Breast/Formula Combo,3 = Formula, 
FeedingChoices= ['Breastmilk','Breast/Formula Combo','Formula']

np.random.seed(1234) # So that the variable values are reproducible

dfnew = pd.DataFrame({'AgeProfile':np.random.choice(AgeProfile, 500, p=[0.048, 0.141, 0.366, 0.358, 0.087]), 
                      'Ethnicity':np.random.choice( Ethnicity,500, p=[0.903,0.003,0.014,0.057,0.004,0.01,0.009]) ,
                      'FeedingChoices' :np.random.choice(FeedingChoices, 500, p=[0.5,0.2,0.3]) , 
                      'Hospitals' : np.random.choice(Hospitals,500, p=[0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.04, 0.05, 0.05, 0.04, 0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05]),
                      'HospitalFeedingSupport':np.random.randint(6,size=(500)),'HomeFeedingSupport':np.random.randint(6,size=(500))})

#dfnew

#Add and Populate the Breastfeeding6months column 

dfnew.loc[dfnew['FeedingChoices']=='Breastmilk', 'Breastfeeding6months']='1'
dfnew.loc[dfnew['FeedingChoices']!='Breastmilk', 'Breastfeeding6months']='2'


display(dfnew)
#df.describe()
print (dfnew.dtypes)

import pandas as pd
import matplotlib as plt
import seaborn as sns

correlation = dfnew.corr()
# display(correlation)
#plt.figure(figsize=(14, 12))
heatmap = sns.heatmap(correlation, annot=True, linewidths=0, vmin=-1, cmap="RdBu_r")

# %% [markdown]
# ###  **Some Value Counts to examine each of the variables

# %%
dfnew['AgeProfile'].value_counts() # Using the value counts function to generate counts of AgeProfiles

# %% [markdown]
# The majority of mothers surveyed are between the ages of 30 and 35 , with a good difference on either side.

# %%
dfnew['Breastfeeding6months'].value_counts() # Using the value counts function to generate counts of Breastfeeding6monthsS

# %% [markdown]
# The results show the numbers for both grps of mothers that continued to breastfeed from that initial week (1) and didnt originally make that choice (2). So the value we look at is no. 1 -265 ,mothers all continued breastfeeding after the 1 st week.

# %%
dfnew['Hospitals'].value_counts() # Using the value counts function to generate counts of Hospitals

# %% [markdown]
# Looking at the numbers above, each hospital was well represented evenly in the survey.

# %%
# 1 =Breastmilk,2 =Breast/Formula Combo,3 = Formula,4 = Unsure 
FeedingChoices= ['1','2','3','4']
dfnew['FeedingChoices'].value_counts() # Using the value counts function to generate counts of Hospitals [5].S

# %%
Overall the Breastfeeding was the highest feeding choice among the 500 mothers surveyed

# %% [markdown]
# ##### Is the level of feeding support given to the mothers surveyed differ between hospitals ?
#
# The Data from HospitalFeedingSupport ( rating 1-5 ,5 been positive) and the hospitals were grouped together using pandas and new dataset was created and graphed. It can be seen that the level of hospital feeding support is of a high standard.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# Adding survey variables to the dataframe:
HospitalFeedingSupport = [5,5,4,3,2]
HomeFeedingSupport = [5,5,4,3,3]
AgeProfile = [20,25,30,35,40 ]
Hospitals = ['National Maternity Hospital',
             'Coombe Women and Infants University Hospital',
             'Cork University Maternity Hospital',
             'University Maternity Hospital Limerick',
             'Our Lady of Lourdes Hospital',
             'University Hospital Galway',
             'Cavan General Hospital',
             'Letterkenny University Hospital',
             'Mayo University Hospital',
             'Midland Regional Hospital Mullingar',
             'Midland Regional Hospital Portlaoise',
             'Portiuncula University Hospital',
             'Sligo University Hospital',
             'South Tipperary General Hospital',
             'St Luke’s General Hospital',
             'University Hospital Kerry',
             'University Hospital Waterford',
             'Wexford General Hospital',
             'National Home Birth Services',
             'Rotunda Hospital']


#Ethnic Characteristic of women who responded to the survey
#1= White Irish ,2= Roma, 3= African, 4 = Asian, 5 = Arabic, 6 = Mixed , 7 = Other
Ethnicity= ['1','2','3','4','5','6','7']


#Create the feeding options
# 1 =Breastmilk,2 =Breast/Formula Combo,3 = Formula, 
FeedingChoices= ['Breastmilk','Breast/Formula Combo','Formula']

np.random.seed(1234) # So that the variable values are reproducible

dfnew = pd.DataFrame({'AgeProfile':np.random.choice(AgeProfile, 500, p=[0.048, 0.141, 0.366, 0.358, 0.087]), 
                      'Ethnicity':np.random.choice( Ethnicity,500, p=[0.903,0.003,0.014,0.057,0.004,0.01,0.009]) ,
                      'FeedingChoices' :np.random.choice(FeedingChoices, 500, p=[0.5,0.2,0.3]) , 
                      'Hospitals' : np.random.choice(Hospitals,500, p=[0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.04, 0.05, 0.05, 0.04, 0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05]),
                      'HospitalFeedingSupport':np.random.randint(6,size=(500)),'HomeFeedingSupport':np.random.randint(6,size=(500))})


TopHospitalSupport =dfnew.groupby('Hospitals')['HospitalFeedingSupport'].count().reset_index()

TopHospitalSupport.columns=['Hospitals','Rating']
TopHospitalSupport = TopHospitalSupport.sort_values('Rating', ascending=False)
TopHospitalSupport


import seaborn
sns.set()         # This command sets the "seaborn" style
TopHospitalSupport.plot(  # This is Pandas-style plotting
   x='Hospitals', 
    y='Rating', 
   kind='bar', 
    legend=False,
    width=0.8
)
#Matplotlib styling of the output:
plt.ylabel("Ratings")
plt.xlabel("Hospitals")
plt.title("Total Hospital Feeding Support per Hospital by women surveyed")
plt.gca().yaxis.grid(linestyle=':')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8f4cad4fbcd6> in <module>
#      64 )
#      65 #Matplotlib styling of the output:
# ---> 66 plt.ylabel("Ratings")
#      67 plt.xlabel("Hospitals")
#      68 plt.title("Total Hospital Feeding Support per Hospital by women surveyed")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# #### **Generate the descriptives table :

# %%
dfnew = pd.DataFrame({'AgeProfile':np.random.choice(AgeProfile, 500, p=[0.048, 0.141, 0.366, 0.358, 0.087]), 
                      'Ethnicity':np.random.choice( Ethnicity,500, p=[0.903,0.003,0.014,0.057,0.004,0.01,0.009]) ,
                      'FeedingChoices' :np.random.choice(FeedingChoices, 500, p=[0.5,0.2,0.3]) , 
                      'Hospitals' : np.random.choice(Hospitals,500, p=[0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.04, 0.05, 0.05, 0.04, 0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05]),
                      'HospitalFeedingSupport':np.random.randint(6,size=(500)),'HomeFeedingSupport':np.random.randint(6,size=(500))})
dfnew.describe().round(2) # full descriptives rounded to 2 decimal

# %% [markdown]
# The average age of mothers surveyed was 32 approx , which is inline with the national age average of mothers  in ireland. Looking at the mean results for the support and decision variables , the response was all on the positive side. These variables results were based on a rating system from 1-5 , 5 being happy with the support.

# %% [markdown]
# ### Generate Data Visualization to examine the relationships between the variables
#
# NB: The KDE , Kernel Density estimation was used. It is a non-parametric way to estimate the PDF of a random variable using automatic bandwidth determination.These are closely related to hisograms.Here we are using Seaborn library.

# %% [markdown]
# #### **1. AgeProfile vs Feeding Choices**

# %%
dfnew = pd.DataFrame({'AgeProfile':np.random.choice(AgeProfile, 500, p=[0.048, 0.141, 0.366, 0.358, 0.087]), 
                      'Ethnicity':np.random.choice( Ethnicity,500, p=[0.903,0.003,0.014,0.057,0.004,0.01,0.009]) ,
                      'FeedingChoices' :np.random.choice(FeedingChoices, 500, p=[0.5,0.2,0.3]) , 
                      'Hospitals' : np.random.choice(Hospitals,500, p=[0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.04, 0.05, 0.05, 0.04, 0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05]),
                      'HospitalFeedingSupport':np.random.randint(6,size=(500)),'HomeFeedingSupport':np.random.randint(6,size=(500))})
import seaborn as sns
import matplotlib.pyplot as plt


sns.displot(data=dfnew, x="AgeProfile", hue="FeedingChoices", kind="kde")

# %% [markdown]
# Conclusions: Looking at the chart above , we can see that with the age grp 30-35 , there is a high density of mothers choosing breastfeeding followed by formula and then a combination . Its a normal distribution as the results decrease as the age profile decreases and increases.

# %% [markdown]
# #### **2. HospitalFeedingSupport vs Feeding Choices**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.displot(data=dfnew, x="HospitalFeedingSupport", hue="FeedingChoices", kind="kde")

# %%
Conclusions: I was hoping to see a postive relationship between the support given by the hospital and the feeding choice 
made by the mothers.From the above chart , we can see the the top feeding choice was Breastmilk with positive rating with positive rating for support
given to the health care professionals in the hospital setting.

# %% [markdown]
# #### **3. Relationship between Hospital FeedingSupport /Feeding Choices/Age Profile**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.displot(dfnew,x="AgeProfile",col ="FeedingChoices",row = "HospitalFeedingSupport")

# %% [markdown]
# Conclusion : Looking at the above plots, we can see there is high no.of mothers in all agegrps that rated the hospital feeding supports poorly.Again mothers in the age profile 30 -35 ,who choose breastfeeding seem to rate the support highly where other women who choose other options didnt think they got the same support.

# %% [markdown]
# #### **4. Relationship between Home FeedingSupport /Feeding Choices and AgeProfile**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.displot(dfnew,x="AgeProfile",col ="FeedingChoices",row = "HomeFeedingSupport")

# %% [markdown]
# Conclusions : From the charts above , Under the Breastfeeding choice , there was a high no. of 30-35 yr old mothers that rated the home support low ( 0) but this rating increased . The rating results for the other two feeding options were about the same. For the 20 - 25 age grp , the ratings were poor for all feeding choices, indicating , these mothers did not rate the support they got at home.

# %% [markdown]
# #### **5.HomeFeedingSupport vs Feeding Choices

# %%
dfnew = pd.DataFrame({'AgeProfile':np.random.choice(AgeProfile, 500, p=[0.048, 0.141, 0.366, 0.358, 0.087]), 
                      'Ethnicity':np.random.choice( Ethnicity,500, p=[0.903,0.003,0.014,0.057,0.004,0.01,0.009]) ,
                      'FeedingChoices' :np.random.choice(FeedingChoices, 500, p=[0.5,0.2,0.3]) , 
                      'Hospitals' : np.random.choice(Hospitals,500, p=[0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.04, 0.05, 0.05, 0.04, 0.06, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05]),
                      'HospitalFeedingSupport':np.random.randint(6,size=(500)),'HomeFeedingSupport':np.random.randint(6,size=(500))})

import seaborn as sns
import matplotlib.pyplot as plt

sns.displot(data=dfnew, x="HomeFeedingSupport", hue="FeedingChoices", kind="kde")

# %% [markdown]
# Conclusions: I was hoping to see a postive relationship between the support given at the home setting and the breastfeeding choice made by the mothers.From the above chart , we can see the the top feeding choice was Breastmilk with positive rating for support given to the health care professionals in the home setting.

# %% [markdown]
# #### **6.HomeFeedingSupport vs Breastfeeding6months**

# %%
dfnew.loc[dfnew['FeedingChoices']=='Breastmilk', 'Breastfeeding6months']='1'
dfnew.loc[dfnew['FeedingChoices']!='Breastmilk', 'Breastfeeding6months']='2'


sns.displot(data=dfnew, x="HomeFeedingSupport", hue="Breastfeeding6months" , kind="kde")

# %%
Conclusion: There is positive relationship between the home feeding support received and the continued feeding choice of breastmilk after the inital week to 6 months -orange line no. 1 . Whereas the blue line are the numbers of mothers who didnt choose breastfeeding at all.

# %% [markdown]
# #### **7.Ethnicity vs FeedingChoices
#
# Using a catplot in Seaborn to access to several axies-level functions that show the relationship between a numerical and one or more categorical variables using one of several visual representations.
#
# Ethnic Characteristic of women who responded to the survey :
#
# 1= White Irish ,2= Roma, 3= African, 4 = Asian, 5 = Arabic, 6 = Mixed , 7 = Other
#
# Ethnicity= ['1','2','3','4','5','6','7']

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.catplot(
    data=dfnew, kind="bar",x="AgeProfile", y="Ethnicity", hue="FeedingChoices",ci="sd", palette="dark", alpha=.6, height=6)

# %% [markdown]
# Conclusions : From the chart above , 5 out of the 7 ethnic groups have a evenly distributed numbers of feeding choices, where the Roma ethnic grp choose Formula and the african group  choose breastmilk .

# %% [markdown]
# #### 8.  Examining the co-relations between the variables - using heatmap [10]

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

correlation = dfnew.corr()
# display(correlation)
#plt.figure(figsize=(14, 12))
heatmap = sns.heatmap(correlation, annot=True, linewidths=0, vmin=-1, cmap="RdBu_r")

# %%
Conclusions: The squares with positive values show direct co-relationships between AgeProfile and HomeFeedingsupport Variables.
    The higher these values , the stronger these relationships are - more red. , So one increases the other will
    The squares with negative values show inverse co-relationship , so the variables AgeProfile and hospitalFeeding support have an inverse relationship.
    The more negative these values get the more inversely proportional they are - more blue.

# %% [markdown]
# ### **General Conclusions from the above Dataset :
#
# - There is a positive relationship between the feeding supports both in the hospital and at home by the healthcare professionals and the feeding choices made by mothers surveyed. It showed more mothers choose breastfeeding and continued to do so til 6 months at least.
# - However there is difference in the support both home and hospital towards mothers that choose other forms of feeding and especially in the younger age grps.
#
# NB: The fact that the highest no, of mothers that took the survey was 30- 35 age grp , this is highly populated. However it doesnt take from the fact that mothers in the other age cateragories rated the support differently.Their opinion counts.
#
# - There was not real relation between ethnicity and the feeding choices. We would need to look at a high number of datapoints to determine this.
# - The average age of mothers taking this survey was 33 years, and here was highest breastfeeding numbers.
# - All hospitals taking part had good feeding support rating scores both at home and in hospital.

# %% [markdown]
# #### References
# [1] https://yourexperience.ie/wp-content/uploads/2020/09/National-Maternity-Experience-Survey-results.pdf
#
# [ 2] https://www.irishexaminer.com/news/arid-30812126.html#:~:text=The%20average%20age%20Irish%20women,first%20baby%20is%2032.5%20years.- Average age for mothers in ireland
#
# [3] https://jech.bmj.com/content/68/4/356 - Ethnicity and Breastfeeding in Ireland
#
# [4] https://www.hse.ie/eng/about/who/healthwellbeing/our-priority-programmes/child-health-and-wellbeing/breastfeeding-healthy-childhood-programme/policies-and-guidelines-breastfeeding/breastfeeding-in-a-healthy-ireland-report.pdf
#
# [5] https://datatofish.com/if-condition-in-pandas-dataframe/
#
# [6]https://www.dataquest.io/blog/pandas-cheat-sheet/
#
# [7] https://www.shanelynn.ie/plotting-with-python-and-pandas-libraries-for-data-visualisation/
#
# [8] https://en.wikipedia.org/wiki/Kernel_density_estimation
#
# [9] https://realpython.com/python-statistics/
#
# [10] https://medium.com/free-code-camp/using-data-science-to-understand-what-makes-wine-taste-good-669b496c67ee#9b0b
